# %% [markdown]
# # AULA match case

# %%
dia =int(input('Digite um numero de 1 a 7: ')) 
if dia == 1:    
    print('Domingo')
elif dia == 2:
    print('Segunda')
elif dia == 3:
    print('Terça')
elif dia == 4:
    print('Quarta')
elif dia == 5:
    print('Quinta')
elif dia == 6:
    print('Sexta')
elif dia == 7:
    print('Sabado')
else:
    print('Dia invalido')
# Out:
# Sabado

# %%
#Match case
dia = int(input('Digite um numero de 1 a 7: '))

match dia:
    case 1:
        print('Domingo')
    case 2:
        print('Segunda')
    case 3:
        print('Terça')
    case 4:
        print('Quarta')
    case 5:
        print('Quinta')
    case 6:
        print('Sexta')
    case 7:
        print('Sabado')
    case _:
        print('Dia invalido')
# Out:
# Domingo

# %%
#Exercício
num1 = float(input('Digite o primeiro numero: '))
num2 = float(input('Digite o segundo numero: '))
operacao = input('Digite o tipo de operação (+, -, *, /): ').strip()

match operacao:
    case "+":
        print(f'Resultado{num1 + num2}')
    case "-":
        print(f'Resultado{num1 - num2}')
    case "/":
        print(f'Resultado{num1 / num2}')
    case "*":
        print(f'Resultado{num1 * num2}')
    case _:
        print('Resultado não reconhecida')

# %%
codigo = int(input('Digite o numero do setor (10-14): '))
match codigo:
    case 10:
        print('Setor: Alimentos')
    case 11:
        print('Setor: Bebidas')
    case 12:
        print('Setor: Limpeza')
    case 13:
        print('Setor: Higiene')
    case 14:
        print('Setor: Hortifruti')
    case _:
        print('Setor Desconhecido')

# %%
#desafio ecommerce
regiao = str(input('Digite a Sigla da regiao em que mora(SP, RJ, MG ou OUTROS)')).strip().upper()

match regiao:
    case "SP":
        valor_frete = 10.0
        prazo_dias = 2
    case "RJ":
        valor_frete = 15.0
        prazo_dias = 3
    case "MG":
        valor_frete = 18.0
        prazo_dias = 4
    case _:
       valor_frete = 50.0
       prazo_dias = 20
print(f'Frete R$ {valor_frete:.2f} | Entrega wm {prazo_dias} dias!')

# %%
valocidade=int(input("Digite a velocidade do carro: "))
if valocidade > 80:
    print("Você foi multado!")
    multa=(valocidade-80)*7
    print("O valor da multa é: R$ {:.2f}".format(multa))
elif valocidade == 80:
    print("Você está na velocidade permitida.")
elif valocidade < 80:
    print("Você está abaixo da velocidade permitida.")
else:
    print("Valor inválido.")
if multa > 0 and multa <= 100:
    print("gravisimo! 5 pontos na carteira!")
    
elif multa == 0:
    print("Tenha um bom dia! Dirija com segurança!")
# Out:
# Você está na velocidade permitida.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#      10 else:
#      11     print("Valor inválido.")
# ---> 12 if multa > 0 and multa <= 100:
#      13     print("gravisimo! 5 pontos na carteira!")
#      15 elif multa == 0:
#
# NameError: name 'multa' is not defined
