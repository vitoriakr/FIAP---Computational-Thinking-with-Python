# %%
# o contador
contador = 1
while contador <= 5:
    print(contador)
    contador += 1
print("FIM")
# Out:
# 1
# 2
# 3
# 4
# 5
# FIM

# %%
# exercicio de despertador
resposta = "s"
while resposta == "s":
    resposta = input('Deseja dormir mais 5 minutos? (s/n): ').lower()
    
    if resposta == "s":
        print('Mais 5 minutos de sono...')
        
print('Bom dia! Hora de acordar!')
# Out:
# Mais 5 minutos de sono...
# Mais 5 minutos de sono...
# Bom dia! Hora de acordar!

# %%
#tabuada
numero = int(input("Digite um número para ver a tabuada: "))
i = 1
while i <= 10:
    print(f'{numero} x {i} = {numero * i}')
    i += 1
# Out:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
#jogo da adivinhação
from random import randint
numero_secreto = randint(1, 100)
tentativas = 0
while True:
    chute = int(input("Digite um número entre 1 e 100: "))
    tentativas += 1
    
    if chute < numero_secreto:
        print("Tente um número maior.")
    elif chute > numero_secreto:
        print("Tente um número menor.")
    else:
        print(f"Parabéns! Você acertou o número {numero_secreto} em {tentativas} tentativas!")
        break
# Out:
# Tente um número maior.
# Tente um número menor.
# Tente um número maior.
# Parabéns! Você acertou o número 70 em 4 tentativas!

# %%
"""
desafio do orçamento
entendendo o while com um novo desafio
"""

orcamento = float(input("Digite o valor do arçamento total: R$ "))
total_gasto = 0
# O loop vai veridicar : o que eu já gastei ainda cabe no meu orçamento?
while total_gasto < orcamento:
    gasto = float(input(f"Digite o valor do gasto: R$ {total_gasto:.2f}: "))
    total_gasto += gasto
    
#quando o taotal gasto for igual ou maior que o orçamento, o loop para e mostra o total gasto
excedente = total_gasto - orcamento
print(f"Você excedeu o orçamento em R$ {excedente:.2f}")
